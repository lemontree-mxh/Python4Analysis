# %%
print("Hello, world!")
# Out:
# Hello, world!

# %%
# %pwd
# Out:
# 'C:\\Users\\maxh'

# %%
b = [1, 2, 3]

# %%
b？
# Out:
#   File "<ipython-input-4-78087d7481a5>", line 1
#     b？
#      ^
# SyntaxError: invalid character in identifier

# %%
b?

# %%
print?

# %%
print??

# %%
b??

# %%
b?

# %%
import pandas as pd

# %%
pd.?
# Out:
#   File "<ipython-input-11-5cd52e6299d4>", line 1
#     pd.?
#        ^
# SyntaxError: invalid syntax

# %%
pd.*load*?

# %%
 # %load print
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-675fd000a2a6> in <module>()
# ----> 1 get_ipython().magic('load print')
#
# ~\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py in magic(self, arg_s)
#    2144         magic_name, _, magic_arg_s = arg_s.partition(' ')
#    2145         magic_name = magic_name.lstrip(prefilter.ESC_MAGIC)
# -> 2146         return self.run_line_magic(magic_name, magic_arg_s)
#    2147
#    2148     #-------------------------------------------------------------------------
#
# ~\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py in run_line_magic(self, magic_name, line)
#    2065                 kwargs['local_ns'] = sys._getframe(stack_depth).f_locals
#    2066             with self.builtin_trap:
# -> 2067                 result = fn(*args,**kwargs)
#    2068             return result
#    2069
#
# ...

# %%
# %timeit print(b)
# Out:
# [1, 2, 3]
# [1, 2, 3]
# [1, 2, 3]
# [1, 2, 3]
# [1, 2, 3]
# [1, 2, 3]
# [1, 2, 3]
# [1, 2, 3]
# [1, 2, 3]
# [1, 2, 3]
# [1, 2, 3]
# [1, 2, 3]
# [1, 2, 3]
# [1, 2, 3]
# [1, 2, 3]
# [1, 2, 3]
# [1, 2, 3]
# [1, 2, 3]
# [1, 2, 3]
# [1, 2, 3]
# [1, 2, 3]
# [1, 2, 3]
# [1, 2, 3]
# [1, 2, 3]
# [1, 2, 3]
# [1, 2, 3]
# [1, 2, 3]
# [1, 2, 3]
# [1, 2, 3]
# [1, 2, 3]
# [1, 2, 3]
# [1, 2, 3]
# [1, 2, 3]
# [1, 2, 3]
# [1, 2, 3]
# [1, 2, 3]
# [1, 2, 3]
# [1, 2, 3]
# [1, 2, 3]
# [1, 2, 3]
# [1, 2, 3]
# [1, 2, 3]
# [1, 2, 3]
# [1, 2, 3]
# [1, 2, 3]
# [1, 2, 3]
# [1, 2, 3]
# [1, 2, 3]
# [1, 2, 3]
# [1, 2, 3]
# [1, 2, 3]
# [1, 2, 3]
# [1, 2, 3]
# [1, 2, 3]
# [1, 2, 3]
# [1, 2, 3]
# [1, 2, 3]
# [1, 2, 3]
# [1, 2, 3]
# [1, 2, 3]
# [1, 2, 3]
# [1, 2, 3]
# [1, 2, 3]
# [1, 2, 3]
# [1, 2, 3]
# [1, 2, 3]
# [1, 2, 3]
# [1, 2, 3]
# [1, 2, 3]
# [1, 2, 3]
# [1, 2, 3]
# [1, 2, 3]
# [1, 2, 3]
# [1, 2, 3]
# [1, 2, 3]
# [1, 2, 3]
# [1, 2, 3]
# [1, 2, 3]
# [1, 2, 3]
# [1, 2, 3]
# [1, 2, 3]
# [1, 2, 3]
# [1, 2, 3]
# ...

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(np.random.randn(50).cumsum())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-09cd4ecfe007> in <module>()
# ----> 1 plt.plot(np.random.randn(50).cumsum())
#
# NameError: name 'np' is not defined

# %%
import numpy as np

# %%
plt.plot(np.random.randn(50).cumsum())

# %%
print(b)
# Out:
# [1, 2, 3]

# %%
print("haha")
# Out:
# haha

# %%
b
# Out:
# [1, 2, 3]

# %%
b.append(4)

# %%
b.insert(1,5)

# %%
b
# Out:
# [1, 5, 2, 3, 4]

# %%
import bisect

# %%
bisect.bisect?

# %%
bisect.bisect(b,2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-549ecb9fc44b> in <module>()
# ----> 1 bisect.bisect(b,2)
#
# NameError: name 'b' is not defined

# %%
b
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-3b5d5c371295> in <module>()
# ----> 1 b
#
# NameError: name 'b' is not defined

# %%
c = [1,2,2,2,4,5,7]

# %%
bisect.bisect(c,2)
# Out:
# 4

# %%
c
# Out:
# [1, 2, 2, 2, 4, 5, 7]

# %%
bisect.bisect(b,6)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-9d347cceb218> in <module>()
# ----> 1 bisect.bisect(b,6)
#
# NameError: name 'b' is not defined

# %%
bisect.bisect(c,6)
# Out:
# 6

# %%
bisect.bisect(c,4)
# Out:
# 5

# %%
bisect.insort(c,4)

# %%
c
# Out:
# [1, 2, 2, 2, 4, 4, 5, 7]

# %%
c[::-1]
# Out:
# [7, 5, 4, 4, 2, 2, 2, 1]

# %%
c[::2]
# Out:
# [1, 2, 4, 5]

# %%
seq1 = ['foo', 'bar', 'baz']

# %%
seq2 = ['one', 'two', 'three']

# %%
zipped = zip(seq1, seq2)

# %%
zipped

# %%
list(zipped)
# Out:
# [('foo', 'one'), ('bar', 'two'), ('baz', 'three')]

# %%
from collections import defaultdict

# %%
by_letter = defaultdict(list)

# %%
for word in words:
    by_letter[word[0]].append(word)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-50876e9f8f17> in <module>()
# ----> 1 for word in words:
#       2     by_letter[word[0]].append(word)
#
# NameError: name 'words' is not defined

# %%
 words = ['apple', 'bat', 'bar', 'atom', 'book']

# %%
for word in words:
    by_letter[word[0]].append(word)

# %%
by_letter
# Out:
# defaultdict(list, {'a': ['apple', 'atom'], 'b': ['bat', 'bar', 'book']})

# %%
by_letter.setdefault('hahaha',[])
# Out:
# []

# %%
by_letter
# Out:
# defaultdict(list,
#             {'a': ['apple', 'atom'],
#              'b': ['bat', 'bar', 'book'],
#              'hahaha': []})

# %%
from collections import defaultdict
by_letter = defaultdict(list)
for word in words:
    by_letter[word[0]].append(word)

# %%
by_letter
# Out:
# defaultdict(list, {'a': ['apple', 'atom'], 'b': ['bat', 'bar', 'book']})

# %%
import re

# %%
def clean_strings(strings):
    result = []
    for value in strings:
        value = value.strip()
        value = re.sub('[!#?]','',value)
        value = value.title()
        result.append(value)
    return result

# %%
states = [' Alabama ', 'Georgia!', 'Georgia', 'georgia', 'FlOrIda',
.....: 'south carolina##', 'West virginia?']

# %%
clean_strings(states)
# Out:
# ['Alabama',
#  'Georgia',
#  'Georgia',
#  'Georgia',
#  'Florida',
#  'South Carolina',
#  'West Virginia']

# %%
"FlOrIda".title()
# Out:
# 'Florida'

# %%
for x in map(remove_punctuation,states):
    print(x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-35-9c64f6325cca> in <module>()
# ----> 1 for x in map(remove_punctuation,states):
#       2     print(x)
#
# NameError: name 'remove_punctuation' is not defined

# %%
some_dict = {'a':1,'b':2,'c':3}

# %%
for key in some_dict:
    print(key)
# Out:
# a
# b
# c

# %%
dict_iterator = iter(some_dict)

# %%
dict_iterator

# %%
list(dict_iterator)
# Out:
# ['a', 'b', 'c']

# %%
def squares(n=10):
    print('Generating squares from 1 to {0}'.format(n**2))
    for i in range(1,n+1):
        yield i**2

# %%
gen = squares()

# %%
gen
# Out:
# <generator object squares at 0x000001ABA9BC5BA0>

# %%
for x in gen:
# Out:
#   File "<ipython-input-44-26cfededbe43>", line 1
#     for x in gen:
#                  ^
# SyntaxError: unexpected EOF while parsing

# %%
for x in gen:
    print(x,end=' ')
# Out:
# Generating squares from 1 to 100
# 1 4 9 16 25 36 49 64 81 100

# %%
gen = (x ** 2 for x in range(100))

# %%
gen
# Out:
# <generator object <genexpr> at 0x000001ABA9BAE518>

# %%
sum(x for x in range(100))
# Out:
# 4950

# %%
sum(x for x in range(101))
# Out:
# 5050

# %%
gen = (x for x in range(100))

# %%
gen
# Out:
# <generator object <genexpr> at 0x000001ABA9BAE570>

# %%
import itertools

# %%
first_letter = lambda x : x[0]

# %%
names = ['Alan', 'Adam', 'Wes', 'Will', 'Albert', 'Steven']

# %%
for letter,names in itertools.groupby(name,first_letter):
    print(letter,list(names))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-b0ab843dbc87> in <module>()
# ----> 1 for letter,names in itertools.groupby(name,first_letter):
#       2     print(letter,list(names))
#
# NameError: name 'itertools' is not defined

# %%
pwd
# Out:
# 'C:\\Users\\maxh\\practice'

# %%
path = 'C:\\Users\\maxh\\github\\examples\\segismundo.txt'

# %%
f = open(path)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-b55632842c59> in <module>()
# ----> 1 f = open(path)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\maxh\\github\\examples\\segismundo.txt'

# %%
path = 'C:\\Users\\maxh\\github\\pydata-book\\examples\\segismundo.txt'

# %%
f = open(path)

# %%
for line in f:
    print(line)
# Out:
# Sue帽a el rico en su riqueza,
#
# que m谩s cuidados le ofrece;
#
#
#
# sue帽a el pobre que padece
#
# su miseria y su pobreza;
#
#
#
# sue帽a el que a medrar empieza,
#
# sue帽a el que afana y pretende,
#
# sue帽a el que agravia y ofende,
#
#
#
# y en el mundo, en conclusi贸n,
#
# todos sue帽an lo que son,
#
# aunque ninguno lo entiende.

# %%
lines = [x.rstrip() for x in open(path)]

# %%
lines
# Out:
# ['Sue帽a el rico en su riqueza,',
#  'que m谩s cuidados le ofrece;',
#  '',
#  'sue帽a el pobre que padece',
#  'su miseria y su pobreza;',
#  '',
#  'sue帽a el que a medrar empieza,',
#  'sue帽a el que afana y pretende,',
#  'sue帽a el que agravia y ofende,',
#  '',
#  'y en el mundo, en conclusi贸n,',
#  'todos sue帽an lo que son,',
#  'aunque ninguno lo entiende.',
#  '']

# %%
f.read(10)
# Out:
# ''

# %%
f.read(9)
# Out:
# ''

# %%
f.close()

# %%
f = open(path)

# %%
f.read(10)
# Out:
# 'Sue帽a el r'

# %%
f.tell()
# Out:
# 11
